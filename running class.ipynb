# %%
def fit(x1, y1, x2, y2):
    m = (y2-y1)/(x2-x1)
    c1 = y1 - m*x1
    return m,c1

# %%
def predict(m,c,x):
    y = m*x+c
    return y

predict(2, 3, 4)
# Out:
# 11

# %%
#base 8 -> base 10
#123 = 3+2*8+1*8*8
def base_8(num):
    count = len(str(num))
    val = []
    det = []
    #print("hi")
    #print(count)
    for i in range(0,count):
        mod = num%10
        rem = num//10
        #print(rem)
        #sol = mod * 10**i
        num = rem
        val.append(str(mod*8**i)) 
        #print(mod ,"*", 10**i)
        #fi = mod ,"*", 10**i
        #print(fi)
        det.append(str(mod) + "*" + str(8**i))
    print("+".join(val))
    print("+".join(det))

base_8(123)
# Out:
# 3+16+64
# 3*1+2*8+1*64

# %%
def base_8(num):
    count = 0
    temp = num
    val = []
    det = []
    final_ans = 0
    magic = 1
    while temp > 0:
        temp = temp // 10
        #print(temp)
        
        mod = num % 10
        #print(count)
        #val.append(f"{mod}*8**{count}") 
        #det.append(f"{mod}*{8**count}")
        val.append(f"{mod}*{magic}") 
        det.append(f"{mod}*{magic}")
        final_ans = final_ans + (mod)*(magic)
        count += 1
        magic *= 8

    
    print("+".join(val))
    print("+".join(det))
    print(final_ans)

base_8(123)
# Out:
# 3*1+3*8+3*64
# 3*1+3*8+3*64
# 219

# %%
#Here is my final code with Print:
# convert Base 8 to Base 10
def Base8_Base10(num):
    base10_num = 0
    i= 0
    print(f"num : {num}")
    while num > 0:
        last_num = num % 10
        base10_num += last_num*(8**i)
        print (f"Last_number is : {last_num}")
        num = num // 10
        i = i+1
    print(f"base10 of num is: {base10_num}")
Base8_Base10(123)
# Out:
# num : 123
# Last_number is : 3
# Last_number is : 2
# Last_number is : 1
# base10 of num is: 83
