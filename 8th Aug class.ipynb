# %%
import math
#sq root of 1
1*1
# Out:
# 1

# %%
#sq root of 4 is 2
2*2
# Out:
# 4

# %%
#sq root of 5
guess = 2.5
guess*guess
# Out:
# 6.25

# %%
lo = 2
hi = 2.5
guess = (lo + hi)/2
print("Guess is",guess)
print("SQRT of 5 is",guess*guess)
# Out:
# Guess is 2.25
# SQRT of 5 is 5.0625

# %%
lo = 2
hi = 2.25
guess = (lo + hi)/2
print("Guess is",guess)
print("SQRT of 5 is",guess*guess)
# Out:
# Guess is 2.125
# SQRT of 5 is 4.515625

# %%
lo = 2.125
hi = 2.25
guess = (lo + hi)/2
print("Guess is",guess)
print("SQRT of 5 is",guess*guess)
# Out:
# Guess is 2.1875
# SQRT of 5 is 4.78515625

# %%
lo = 2.1875
hi = 2.25
guess = (lo + hi)/2
print("Guess is",guess)
print("SQRT of 5 is",guess*guess)
# Out:
# Guess is 2.21875
# SQRT of 5 is 4.9228515625

# %%
lo = 2.21875
hi = 2.25
guess = (lo + hi)/2
print("Guess is",guess)
print("SQRT of 5 is",guess*guess)
# Out:
# Guess is 2.234375
# SQRT of 5 is 4.992431640625

# %%
lo = 2.234375
hi = 2.25
guess = (lo + hi)/2
print("Guess is",guess)
print("SQRT of 5 is",guess*guess)
# Out:
# Guess is 2.2421875
# SQRT of 5 is 5.02740478515625

# %%
lo = 2.234375
hi = 2.2421875
guess = (lo + hi)/2
print("Guess is",guess)
print("SQRT of 5 is",guess*guess)
# Out:
# Guess is 2.23828125
# SQRT of 5 is 5.0099029541015625

# %%
lo = 2.234375
hi = 2.23828125
guess = (lo + hi)/2
print("Guess is",guess)
print("SQRT of 5 is",guess*guess)
# Out:
# Guess is 2.236328125
# SQRT of 5 is 5.001163482666016

# %%
lo = 2.234375
hi = 2.236328125
guess = (lo + hi)/2
print("Guess is",guess)
print("SQRT of 5 is",guess*guess)
# Out:
# Guess is 2.2353515625
# SQRT of 5 is 4.996796607971191

# %%
lo = 2.2353515625
hi = 2.236328125
guess = (lo + hi)/2
print("Guess is",guess)
print("SQRT of 5 is",guess*guess)
# Out:
# Guess is 2.23583984375
# SQRT of 5 is 4.998979806900024

# %%
lo = 2.23583984375
hi = 2.236328125
guess = (lo + hi)/2
print("Guess is",guess)
print("SQRT of 5 is",guess*guess)
# Out:
# Guess is 2.236083984375
# SQRT of 5 is 5.000071585178375

# %%
math.sqrt(5)
# Out:
# 2.23606797749979

# %%
def sqrtfunc(num1):
    num = num1
    lo = 1
    hi = num/2
    guess = 1
    sqrt_is = guess*guess
    while True:
        guess = (lo + hi)/2
        sqrt_is = guess*guess
        if abs(sqrt_is-num) < 1e-9:
            return guess
            break
        elif sqrt_is > num:
            
            hi = guess
            #print("hi is",hi)
        elif sqrt_is < num:
            #print("printz")
            lo = guess

sqrtfunc(400)
# Out:
# 19.9999999999834

# %%
num = 14
guess = 1
lo = 1.14
hi = 2

#for i in range(100):
while True:
  mid = (lo+hi)/2
  #print("lo and hi are",lo,hi)
  guess = mid
  #print("new Guess is ", guess)
  ans = 10**guess
  #print("av tak ka ans is", ans)
  if abs(ans-num)<1e-9:
      #print(lo)
      #print(hi)
      print("found the ans",guess)
      break
  elif ans > num:
    hi = guess
    #print("1")
  elif ans < num:
    lo = guess
    #print("2")
# Out:
# found the ans 1.146128035680158

# %%
#write a func to cal dist b/w x1,y1,x2,y2

def distfunc(x1,y1,x2,y2):
    base = (x2-x1)**2
    height = (y2-y2)**2
    hypo = base+height
    print (base,height)
    return(sqrtfunc(hypo))


distfunc(-2,2,1,6)
# Out:
# 9 0
# 2.999999999970896
